# %%
import numpy as np
import random
import time
import pandas as pd
import matplotlib.pyplot as plt
import time
#import seaborn

# %%
def draw_transition_matrix(T,size):
    matrix=np.zeros((size,size))
    for i in range(T.shape[0]):
        matrix[T[i][0]-1][T[i][1]-1]=T[i][2]
    return matrix

# %%
def value_iteration(T,gamma,epsilon,R):
    size=len(R)
    actions=T.shape[0]
    Q=pd.DataFrame(np.zeros((size,actions)))
    v=np.zeros((size,1))
    iterations=0
    policy=np.zeros((size,1))
    Vold=np.zeros((size,1))+epsilon+2
    iterations=0
    start=time.time()
    history=v
    while True: #int(max(abs(Vold-v))) > epsilon:
        for i in range(actions):
            Q.iloc[:,i]=R+gamma*(np.dot(T[i],v))
        Vold=v
        v=np.array([Q.max(1)]).T
        history=np.append(history,v,axis=1)
        policy=Q.idxmax(1)
        iterations=iterations+1

        if max(abs(Vold-v)) < epsilon:
            print (iterations*size*actions)
            end=time.time()
            print(end-start)
            break
    return v,policy,history

# %%
def policy_iteration(T,gamma,epsilon,R):
    size=len(R)
    actions=T.shape[0]
    Q=pd.DataFrame(np.zeros((size,actions)))
    policy=np.ones((size,1))*random.randint(0, actions-1)
    Tpi=T[0]*0
    v=np.zeros((size,1))
    iterations=0
    p_test=np.ones((size,1))*1000
    vold=np.ones((size,1))*1000
    start=time.time()
    while 1000 in p_test:
        for i in range(size):
            Tpi[i]=T[int(policy[i])][i]
        v=np.dot(np.linalg.inv(np.identity(size)-gamma*Tpi),R)
        for i in range(actions):
            Q.iloc[:,i]=R+gamma*np.dot(T[i],v)
            #Q.iloc[:,i]=np.dot(T[i],gamma*v+R)
        policy_value=np.array([Q.idxmax(1)]).T
        iterations=iterations+size**1.4
        value=np.array([Q.max(1)]).T
        if np.all(policy_value==policy):
            p_test=policy
            print (iterations)
            end=time.time()
            print(end-start)
            break
        else:
            policy=policy_value
    return policy,value

# %%
def policy_iteration_m(T,gamma,epsilon,R):
    size=len(R)
    actions=T.shape[0]
    Q=pd.DataFrame(np.zeros((size,actions)))
    policy=np.ones((size,1))*random.randint(0, actions-1)
    Tpi=T[0]*0
    #v=np.zeros((size,1))*1000
    v=np.zeros((size,1))*0
    iterations=0
    #p_test=np.ones((size,1))*1000
    #vold=np.ones((size,1))*1000
    #value=np.ones((size,1))*10000
    p_test=np.ones((size,1))*0
    vold=np.ones((size,1))*0
    value=np.ones((size,1))*0
    start=time.time()
    history=value
    #while 1000 in p_test:
    while True:
        #iterations=iterations+size**1.4
        for i in range(size):
            Tpi[i]=T[int(policy[i])][i]
        v=np.dot(np.linalg.inv(np.identity(size)-gamma*Tpi),R)
        for i in range(actions):
            Q.iloc[:,i]=R+gamma*np.dot(T[i],v)
            iterations=iterations+size**1.4
            #Q.iloc[:,i]=np.dot(T[i],gamma*v+R)
        policy_value=np.array([Q.idxmax(1)]).T
        vold=value
        value=np.array([Q.max(1)]).T
        history=np.append(history,value,axis=1)
        if max(abs(vold-value)) < epsilon:
            p_test=policy
            print (iterations)
            end=time.time()
            print(end-start)
            break
        else:
            policy=policy_value
    return policy,value,history

# %%
def prioritized_sweeping(T,gamma,epsilon,R):
    size=len(R)
    actions=T.shape[0]
    Q=pd.DataFrame(np.zeros((size,actions)))
    v=np.zeros((size,1))+epsilon+2
    iterations=0
    policy=np.zeros((size,1))
    Vold=np.zeros((size,1))
    iterations=0
    start=time.time()
    H=np.random.rand(size,1)+epsilon
    history=v
    while True: 
        state=H.argmax()
        for i in range(actions):
            Q.iloc[:,i]=R+gamma*(np.dot(T[i],v))
        Vold=float(v[state])
        v[state]=Q.iloc[state,:].max()
        policy=Q.iloc[state,:].idxmax()
        delta=([abs(Vold-v[state])])
        iterations=iterations+1
        history=np.append(history,v,axis=1)
        for i in range(actions):
            H=np.maximum(H,delta*np.array([T[i][state]]).T)
            if i==0:
                H[state]=delta*np.array([T[i][state]]).T[state]
        if  np.max(H) < epsilon:
            print (iterations)
            end=time.time()
            print(end-start)
            break
    return v,policy,history

# %%
T1=np.loadtxt("Action01.txt")
T2=np.loadtxt("Action02.txt")
T3=np.loadtxt("Action03.txt")
T4=np.loadtxt("Action04.txt")
T5=np.loadtxt("Action05.txt")
T6=np.loadtxt("Action06.txt")
R=np.loadtxt("Rewards.txt")
R=np.array([R]).T

# %%
T1=draw_transition_matrix(T1,135)
T2=draw_transition_matrix(T2,135)
T3=draw_transition_matrix(T3,135)
T4=draw_transition_matrix(T4,135)
T5=draw_transition_matrix(T5,135)
T6=draw_transition_matrix(T6,135)
# Out:
# /home/lucas/.local/lib/python3.5/site-packages/ipykernel/__main__.py:4: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future

# %%
T=np.array((T1,T2,T3,T4,T5,T6))

# %%
v_vi,p_vi,h_vi=value_iteration(T,0.8,0.001,R)
plt.imshow(v_vi.reshape((9,15)), cmap='gray',interpolation='nearest')
plt.show()
# Out:
# 21870
# 0.05942416191101074

# %%
p_pi,v_pi=policy_iteration(T,0.85,0.1,R)
plt.imshow(v_pi.reshape((9,15)), cmap='gray',interpolation='nearest')
plt.show()
# Out:
# 18248.23549225179
# 0.07176995277404785

# %%
p_pim,v_pim,h_pim=policy_iteration_m(T,0.99,0.001,R)
plt.imshow(v_pim.reshape((9,15)), cmap='gray',interpolation='nearest')
plt.show()
# Out:
# 109489.41295351092
# 0.07293558120727539

# %%
v_ps,p_ps,h_ps=prioritized_sweeping(T,0.99,0.001,R)
plt.imshow(v_ps.reshape((9,15)), cmap='gray',interpolation='nearest')
plt.show()
# Out:
# 21481
# 153.21783328056335

# %%
plt.plot(h_vi[12],label='estado 12')
plt.plot(h_vi[120],label='estado 120')
plt.xlabel('iteração')
plt.ylabel('valor')
plt.legend()
plt.show()

# %%
##Comparacao entre vi e pim##
plt.plot(h_pim[120],label='Policy iteration')
plt.plot(h_vi[120],label='Value iteration')
#plt.plot(h_ps[120],label='Prioritized Sweeping')
plt.legend()
plt.show()

# %%
v_vi2,p_vi2,h_vi2=value_iteration(T,0.8,0.001,R)
plt.plot(h_vi[120],label='fator de desconto 0.9')
plt.plot(h_vi2[120],label='fator de desconto 0.99')
plt.legend()
plt.show()
# Out:
# 21870
# 0.06964349746704102
